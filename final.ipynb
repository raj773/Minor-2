# %%
import pandas as pd
import numpy as np
dataset=pd.read_csv(r"C:\Users\hp\Downloads\raj.csv")

x=dataset.iloc[:,:-1]
y=dataset.iloc[:,8]
from sklearn.preprocessing import LabelEncoder
labelencoder_x=LabelEncoder()
x=x.apply(LabelEncoder().fit_transform)
from sklearn.tree import DecisionTreeClassifier
Reg = DecisionTreeClassifier()
Reg.fit(x.iloc[:,1:8],y)
dataset2=pd.read_csv(r"C:\Users\hp\Downloads\raj1.csv")
x1=dataset2.iloc[:,:]
from sklearn.preprocessing import LabelEncoder
labelencoder_x=LabelEncoder()
x1=x1.apply(LabelEncoder().fit_transform)

    
    



import numpy as np 
import pandas as pd
from sklearn.tree import DecisionTreeClassifier





my_data = pd.read_csv(r"C:\Users\hp\Downloads\CSVDemo.csv")
my_data
my_data.columns




def gini_index(groups, classes):
	# count all samples at split point
	n_instances = float(sum([len(group) for group in groups]))
	# sum weighted Gini index for each group
	gini = 0.0
	for group in groups:
		size = float(len(group))
		# avoid divide by zero
		if size == 0:
			continue
		score = 0.0
		# score the group based on the score for each class
		for class_val in classes:
			p = [row[-1] for row in group].count(class_val) / size
			score += p * p
		# weight the group score by its relative size
		gini += (1.0 - score) * (size / n_instances)
	return gini
X = my_data[['no_of_visit', 'no_of_times_not_purchase', 'product_quantity',
       'purchase_amount']].values
def test_split(index, value, dataset):
	left, right = list(), list()
	for row in dataset:
		if row[index] < value:
			left.append(row)
		else:
			right.append(row)
	return left, right




y = my_data["valued customer"]
def split(node, max_depth, min_size, depth):
	left, right = node['groups']
	del(node['groups'])
	# check for a no split
	if not left or not right:
		node['left'] = node['right'] = to_terminal(left + right)
		return
	# check for max depth
	if depth >= max_depth:
		node['left'], node['right'] = to_terminal(left), to_terminal(right)
		return
	# process left child
	if len(left) <= min_size:
		node['left'] = to_terminal(left)
	else:
		node['left'] = get_split(left)
		split(node['left'], max_depth, min_size, depth+1)
	# process right child
	if len(right) <= min_size:
		node['right'] = to_terminal(right)
	else:
		node['right'] = get_split(right)
		split(node['right'], max_depth, min_size, depth+1)





from sklearn.model_selection import train_test_split





X_trainset, X_testset, y_trainset, y_testset = train_test_split(X, y, test_size=0.2, random_state=4)

def entropy(target_col):  
    
    elements,counts = np.unique(target_col,return_counts = True)  
    entropy = np.sum([(-counts[i]/np.sum(counts))*np.log2(counts[i]/np.sum(counts)) for i in range(len(elements))])  
    return entropy


y_trainset.shape





X_testset.shape



def decision_tree(train, test, max_depth, min_size):
	tree = build_tree(train, max_depth, min_size)
	predictions = list()
	for row in test:
		prediction = predict(tree, row)
		predictions.append(prediction)
	return(predictions)
cusTree = DecisionTreeClassifier(criterion="entropy", max_depth = 4)
cusTree # it shows the default parameters




cusTree.fit(X_trainset,y_trainset)

def get_split(dataset):
	class_values = list(set(row[-1] for row in dataset))
	b_index, b_value, b_score, b_groups = 999, 999, 999, None
	for index in range(len(dataset[0])-1):
		for row in dataset:
			groups = test_split(index, row[index], dataset)
			gini = gini_index(groups, class_values)
			if gini < b_score:
				b_index, b_value, b_score, b_groups = index, row[index], gini, groups
	return {'index':b_index, 'value':b_value, 'groups':b_groups}
def predict(a,b,*c):
    x=cusTree.predict([[a,b,*c]])
    return(x)




predTree = cusTree.predict(X_testset)
def predicts(query,tree,default = 1):  
    
    for key in list(query.keys()):  
        if key in list(tree.keys()):  
            
            try:  
                result = tree[key][query[key]]   
            except:  
                return default  
    
            result = tree[key][query[key]]  
            
            if isinstance(result,dict):  
                return predict(query,result)  
            else:  
                return result




predTree





np.array(y_testset)





from sklearn import metrics
import matplotlib.pyplot as plt
print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_testset, predTree)*100)





 








my_data2 = pd.read_csv(r"C:\Users\hp\Downloads\rajcsv.csv")
X2 = my_data2[['no_of_visit', 'no_of_times_not_purchase', 'product_quantity',
       'purchase_amount']].values
y2=my_data2["id"].values
print(dataset2)
print("PREDICT")
for i in range(len(x1)):
    m=[x1["customer_age"][i],x1["gender"][i],x1["marriage_status"][i],x1["no_of_visit"][i],x1["no_of_times_not_purchase"][i],x1["product_quantity"][i],x1["purchase_amount"][i]]
    r=Reg.predict([m])
    print(i+1,r[0])
# Out:
# DecisionTrees's Accuracy:  91.66666666666666
#       id  customer_age  gender marriage_status  no_of_visit  \
# 0      1            25    Male       Unmarried            7
# 1      2            56    Male         Married           63
# 2      3            21  Female         Married           25
# 3      4            54    Male         Married           55
# 4      5            26    Male       Unmarried           99
# 5      6            56    Male         Married           59
# 6      7            14  Female       Unmarried            9
# 7      8            65  Female         Married           73
# 8      9            25    Male       Unmarried           21
# 9     10            16  Female       Unmarried           16
# 10    11            39    Male         Married           41
# 11    12            45  Female         Married           39
# 12    13            25  Female         Married           45
# 13    14            63  Female         Married           26
# ...

# %%
dataset
# Out:
#       id  customer_age  gender marriage_status  no_of_visit  \
# 0      1            25    Male       Unmarried            7
# 1      2            56    Male         Married           63
# 2      3            21  Female         Married           25
# 3      4            54    Male         Married           55
# 4      5            26    Male       Unmarried           99
# 5      6            56    Male         Married           59
# 6      7            14  Female       Unmarried            9
# 7      8            65  Female         Married           73
# 8      9            25    Male       Unmarried           21
# 9     10            16  Female       Unmarried           16
# 10    11            39    Male         Married           41
# 11    12            45  Female         Married           39
# 12    13            25  Female         Married           45
# 13    14            63  Female         Married           26
# 14    15            16    Male       Unmarried            8
# ...
